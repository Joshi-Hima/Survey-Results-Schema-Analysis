# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshi-Hima/Survey-Results-Schema-Analysis/blob/main/Survey_results_schema.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
schema_df = pd.read_csv('/content/drive/MyDrive/TechAxis(Data Science)/survey_results_schema.csv')
schema_df
# Out:
#                 Column                                       QuestionText
# 0           Respondent  Randomized respondent ID number (not in order ...
# 1           MainBranch  Which of the following options best describes ...
# 2             Hobbyist                            Do you code as a hobby?
# 3                  Age  What is your age (in years)? If you prefer not...
# 4           Age1stCode  At what age did you write your first line of c...
# ..                 ...                                                ...
# 56  WebframeWorkedWith  Which web frameworks have you done extensive d...
# 57       WelcomeChange  Compared to last year, how welcome do you feel...
# 58         WorkWeekHrs  On average, how many hours per week do you wor...
# 59           YearsCode  Including any education, how many years have y...
# 60        YearsCodePro  NOT including education, how many years have y...
#
# [61 rows x 2 columns]

# %% [markdown]
# Change the index directly from read_csv

# %%
schema_df = pd.read_csv('/content/drive/MyDrive/TechAxis(Data Science)/survey_results_schema.csv', index_col = 'Column')
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.loc['YearsCode']
# Out:
# QuestionText    Including any education, how many years have y...
# Name: YearsCode, dtype: object

# %%
schema_df.loc['YearsCode', 'QuestionText']  #yearscode ko questiontext hereko
# Out:
# 'Including any education, how many years have you been coding in total?'

# %% [markdown]
# # Change the index of df to Respondent

# %%
public_df = pd.read_csv('/content/drive/MyDrive/TechAxis(Data Science)/survey_results_public.csv', index_col = 'Respondent')
public_df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
public_df.head(3)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
# 3              I code primarily as a hobby      Yes  NaN         15      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
#
#            CurrencySymbol  ...                  SurveyEase  \
# Respondent                 ...
# 1                     EUR  ...  Neither easy nor difficult
# 2                     GBP  ...                         NaN
# 3                     NaN  ...  Neither easy nor difficult
#
#                      SurveyLength Trans  \
# Respondent
# ...

# %% [markdown]
# # Hobbbyist Question text access
#
# ```
# # This is formatted as code
# ```

# %%
schema_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, Respondent to YearsCodePro
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   QuestionText  61 non-null     object
# dtypes: object(1)
# memory usage: 3.0+ KB

# %%
schema_df.loc['Hobbyist', 'QuestionText']
# Out:
# 'Do you code as a hobby?'

# %% [markdown]
# # Sort index alphabetically

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.sort_index()
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.sort_index(ascending = False)
# Out:
#                                                          QuestionText
# Column
# YearsCodePro        NOT including education, how many years have y...
# YearsCode           Including any education, how many years have y...
# WorkWeekHrs         On average, how many hours per week do you wor...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# ...                                                               ...
# ConvertedComp       Salary converted to annual USD salaries using ...
# CompTotal           What is your current total compensation (salar...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# Age1stCode          At what age did you write your first line of c...
# Age                 What is your age (in years)? If you prefer not...
#
# [61 rows x 1 columns]

# %% [markdown]
# # Filter respondents from Nepal

# %%
public_df['Country'] == 'Nepal'
# Out:
# Respondent
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 64858    False
# 64867    False
# 64898    False
# 64925    False
# 65112    False
# Name: Country, Length: 64461, dtype: bool

# %% [markdown]
# # How many are from Nepal

# %%
(public_df['Country'] == 'Nepal').value_counts()
# Out:
# Country
# False    64219
# True       242
# Name: count, dtype: int64

# %% [markdown]
# # Getting Nepal DataFrame

# %%
public_df[public_df['Country'] == 'Nepal']
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 173                 I am a developer by profession      Yes  26.0         13
# 275                 I am a developer by profession       No   NaN         18
# 623                    I code primarily as a hobby      Yes  18.0         12
# 807                 I am a developer by profession      Yes  34.0         26
# 1355                I am a developer by profession      Yes  26.0         15
# ...                                            ...      ...   ...        ...
# 64711               I am a developer by profession      Yes  19.0         16
# 65064               I am a developer by profession      Yes   NaN         17
# 65171               I am a developer by profession      Yes   NaN         20
# 65179       I am a student who is learning to code       No   NaN        NaN
# 63820                                          NaN      Yes   NaN         17
#
# ...

# %%
filter_nepal = public_df['Country'] == 'Nepal'

# %%
public_df[filter_nepal]
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 173                 I am a developer by profession      Yes  26.0         13
# 275                 I am a developer by profession       No   NaN         18
# 623                    I code primarily as a hobby      Yes  18.0         12
# 807                 I am a developer by profession      Yes  34.0         26
# 1355                I am a developer by profession      Yes  26.0         15
# ...                                            ...      ...   ...        ...
# 64711               I am a developer by profession      Yes  19.0         16
# 65064               I am a developer by profession      Yes   NaN         17
# 65171               I am a developer by profession      Yes   NaN         20
# 65179       I am a student who is learning to code       No   NaN        NaN
# 63820                                          NaN      Yes   NaN         17
#
# ...

# %% [markdown]
# # Lets see how many Nepali people are employed

# %%
public_df.loc[filter_nepal, 'Employment']
# Out:
# Respondent
# 173      Independent contractor, freelancer, or self-em...
# 275                     Not employed, but looking for work
# 623                                                Student
# 807                                     Employed full-time
# 1355                                    Employed full-time
#                                ...
# 64711                   Not employed, but looking for work
# 65064                                   Employed full-time
# 65171                                   Employed full-time
# 65179                                              Student
# 63820                   Not employed, but looking for work
# Name: Employment, Length: 242, dtype: object

# %%
public_df.loc[filter_nepal, 'Employment'].value_counts()
# Out:
# Employment
# Employed full-time                                      136
# Student                                                  53
# Not employed, but looking for work                       25
# Independent contractor, freelancer, or self-employed     21
# Employed part-time                                        6
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
public_df.loc[filter_nepal, 'Employment'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Employment'>

# %%
public_df.loc[filter_nepal, 'Employment'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>
